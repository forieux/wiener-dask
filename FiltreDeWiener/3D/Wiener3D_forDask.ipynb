# %%
from dask_jobqueue import PBSCluster
cluster = PBSCluster(cores = 24, memory = '32GB', job_extra=['-P decowska'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7113e7819079> in <module>
# ----> 1 from dask_jobqueue import PBSCluster
#       2 cluster = PBSCluster(cores = 24, memory = '32GB', job_extra=['-P decowska'])
#
# ModuleNotFoundError: No module named 'dask_jobqueue'

# %%
cluster.scale()

# %%
from dask.distributed import Client
client = Client(cluster)
client
# Out:
# <Client: scheduler='tcp://160.228.199.52:36468' processes=0 cores=0>

# %%
client.scheduler_info()['services']
# Out:
# {'dashboard': 8787}

# %%
client
# Out:
# <Client: scheduler='tcp://160.228.199.52:36468' processes=2 cores=48>

# %%
import forDaskCluster as fdc

# %%
n = 64
quad = fdc.measuring(n)
quad
# Out:
# num de dimension: 64
# load time: 0.4354
# scheduling time: 35.4599
# compute time: 40.0113
# total time: 75.9065
# dask.array<stack, shape=(64, 2048, 2048), dtype=float64, chunksize=(1, 2048, 2048)>

# %%
quad.persist()
# Out:
# dask.array<stack, shape=(64, 2048, 2048), dtype=float64, chunksize=(1, 2048, 2048)>

# %%
# %%time
quad.compute()
# Out:
# CPU times: user 5.13 s, sys: 8.83 s, total: 14 s
# Wall time: 31.7 s
# array([[[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]],
#
#        [[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]],
#
#        [[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]],
#
#        ...,
#
#        [[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]],
#
#        [[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]],
#
#        [[-4.37741404e-04, -4.01863837e-04,  3.64419128e-04, ...,
#          -3.13097639e-04, -4.02033830e-04, -7.69725157e-05],
#         [-1.47160047e-04, -2.62433278e-04,  1.15638151e-04, ...,
#           1.77195127e-03,  1.40102337e-03, -2.74084417e-04],
#         [-8.95433558e-04,  6.30724391e-05,  6.00990466e-04, ...,
#           8.02371640e-04,  1.56317245e-03, -5.44536280e-04],
#         ...,
#         [-1.39822703e-03, -9.38370175e-04,  4.51595735e-04, ...,
#           1.03511818e-03,  1.40039247e-03,  2.27133874e-03],
#         [ 5.88321556e-04, -5.22786461e-04,  3.51622745e-04, ...,
#           7.07409244e-04, -1.41827565e-04,  1.19378673e-03],
#         [-1.14177010e-03, -9.93470261e-05,  3.22489924e-04, ...,
#          -1.09440529e-03, -1.36697153e-03,  4.80397017e-04]]])

# %%
fdc.show_images()

# %%
fdc.show_courbes()
